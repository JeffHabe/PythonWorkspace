# %% [markdown]
#  lib import 為 * ,在使用時可不使用物件
# %matplotlib inline 是把可以將matplotlib的圖表直接嵌入到Notebook之中

# %%
from numpy import *
from scipy.signal import savgol_filter
from scipy.interpolate import * 
from matplotlib.pyplot import *
from scipy.interpolate import CubicSpline
from scipy import interpolate
# %matplotlib inline

# %%
import csv 
data={}
f = open('0201T3.csv', 'r')
for row in csv.DictReader(f):
    data[row['時間']]=row['值']
f.close()

# %%
def rsq(x,y,pfit):
    if (len(y)==len(pfit)):
          Sresid =(y - pfit)
    else:
        Sresid =(y - polyval(pfit,x))
    SSresid= sum(pow(Sresid,2))
    SStotal=len(y)*var(y)
    rsq=1-SSresid/SStotal
    return rsq

def squared_error(ys_orig,ys_line):
    return sum((ys_line-ys_orig)**2)

def coeff_of_determination(ys_orig, ys_line):
    y_mean_line = [mean(ys_orig) for y in ys_orig]
    squared_error_regr = squared_error(ys_orig,ys_line)
    squared_error_y_mean = squared_error(ys_orig,y_mean_line)   
    return 1 - ( squared_error_regr / squared_error_y_mean)

def least_square(fuc,ys_orig,m,n,x):
    ys_line=polyval(fuc,x)
    err=squared_error(ys_orig,ys_line)
    lsq=err/(m-n-1)
    return lsq

# %%
def cubic_spline(x, y):
    """
    Parameters
    ----------
    x  : list of floats
    y  : list of floats
    
    Returns
    -------  
    list of list of floats
    """
    n = len(x) - 1
    h = [x[i+1]-x[i] for i in range(n)]
    al = [3*((y[i+1]-y[i])/h[i] - (y[i]-y[i-1])/h[i-1]) for i in range(1,n)]
    al.insert(0,0)
    l = [1] * (n+1)
    u = [0] * (n+1)
    z = [0] * (n+1)
    for i in range(1, n):
        l[i] = 2*(x[i+1]-x[i-1]) - h[i-1]*u[i-1]
        u[i] = h[i]/l[i]
        z[i] = (al[i] - h[i-1]*z[i-1])/l[i]
        
    b = [0] * (n+1)
    c = [0] * (n+1)
    d = [0] * (n+1)
    for i in range(n-1, -1, -1):    #for i in reversed(range(n)):
        c[i] = z[i] - u[i]*c[i+1]
        b[i] = (y[i+1]-y[i])/h[i] - h[i]*(c[i+1] + 2*c[i])/3
        d[i] = (c[i+1]-c[i])/(3*h[i])
    return [y, b, c, d]

# %%
def printfx(cbsp):
    d=0.0
    c=0.0
    b=0.0
    a=0.0

    for i  in range(len(cbsp[0])):
                    d=cbsp[0][i]
                    c=cbsp[1][i]    
                    b=cbsp[2][i]
                    a=cbsp[3][i]
                    print( '{:>4d} ~ {:>4d}   {: >+5.6f}( x - {: d})^3{: >+5.4f}( x - {: d} )^2{: >+5.4f}( x - {: d} ){: >+5.4f}'.format(i,i+1,a,i,b,i,c,i,d) )

# %%
def cbspVal(x,cbF):
    # prepare data for plotting the splines
    xs=[]
    xs=arange(len(x))
    ys = []
    for i in range(len(x)):
        ys.append(cbF[0][i] + cbF[1][i]*(xs[i]-i) + cbF[2][i]*(xs[i]-i)**2 + cbF[3][i]*(xs[i]-i)**3)
    return xs,ys

# %%
###### import math  
import matplotlib.pyplot as plt
import numpy as np

  # the function to be interpolated
def f(x):
    return math.e ** x
    
# input
interval = 3
#x = [i for i in range(interval + 1)]
#y = [f(i) for i in range(interval + 1)]
x=np.arange(5)

y=[-9,-12,0,21,55]
# process
a = cubic_spline(x, y)
print(len(a))
print()
print(a)
print()
printfx(a)
# prepare data for plotting the splines
xs,ys=cbspVal(x,a)
print(ys)
# prepare data for plotting the given function
#x = np.linspace(0, 5, interval * points_per_interval - (interval - 1))
#y = [f(x[i]) for i in range(len(x))]
#x=np.arange(5)
#y=[-9,-12,0,21,55]

#plt.plot(x, y, 'k.-', xs[0], ys[0], 'r.--', xs[1], ys[1], 'g.--', xs[2], ys[2], 'b.--',xs[3],ys[3],'--',xs[4],ys[4],'--')
#plt.plot(x,y,'k-',xs,ys,'r--')
#plt.title('Cubic Spline')

#plt.xlabel('x')
#plt.ylabel('y')
#plt.show()

# cubic spline interpolation
# author : worasait suwannik
# date   : apr 2015
# Out:
# 4
#
# [[-9, -12, 0, 21, 55], [-6.6071428571428577, 4.2142857142857144, 16.75, 27.785714285714285, 0], [0.0, 10.821428571428571, 1.7142857142857144, 9.3214285714285712, 0], [3.6071428571428572, -3.035714285714286, 2.5357142857142856, -3.1071428571428572, 0]]
#
#    0 ~    1   +3.607143( x -  0)^3+0.0000( x -  0 )^2-6.6071( x -  0 )-9.0000
#    1 ~    2   -3.035714( x -  1)^3+10.8214( x -  1 )^2+4.2143( x -  1 )-12.0000
#    2 ~    3   +2.535714( x -  2)^3+1.7143( x -  2 )^2+16.7500( x -  2 )+0.0000
#    3 ~    4   -3.107143( x -  3)^3+9.3214( x -  3 )^2+27.7857( x -  3 )+21.0000
#    4 ~    5   +0.000000( x -  4)^3+0.0000( x -  4 )^2+0.0000( x -  4 )+55.0000
# [-9.0, -12.0, 0.0, 21.0, 55]

# %% [markdown]
# savgol_filter 是透過Savitzky-Golay平滑去噪

# %%
i=0
t=[]
v=[]
for value in data.values():
    t.append(i)
    v.append(float(value))
    i+=1
cs=cubic_spline(t,v)
print(len(cs[0]))
tck,u=interpolate.splprep([t,v],s=0.0)
x_i,y_i= interpolate.splev(u,tck)

sgf=savgol_filter(array(v),11,2)
#csx_i,csy_i=cbspVal(t,cs)
#printfx(cs)
#plot(t,v,'o')
#plot(t,sgf,'-')
#plot(t,cs(t))

#plot(t,csy_i)
plot(t, v, 'bo',t,sgf, 'r--')
legend(['data',  'cubicS'], loc='best')
print(coeff_of_determination(array(v),sgf))
#print(coeff_of_determination(array(v),y_i))
#print(coeff_of_determination(array(v),csy_i))
'''av=array(v)
am=mean(av)
print(am)
a=[mean(av) for y in av]
print(a)
print(rsq(t,v,sgf))
print(coeff_of_determination(array(v),sgf))
'''
# Out:
# 1285
# 0.993938614339
# 'av=array(v)\nam=mean(av)\nprint(am)\na=[mean(av) for y in av]\nprint(a)\nprint(rsq(t,v,sgf))\nprint(coeff_of_determination(array(v),sgf))\n'

# %% [markdown]
# 下面程式為把全部Data value 中特定區域取出來

# %%
def mkfile():
    with open('pt.csv','wt',newline='') as csvFile:
        csvHeader=["start","end","polyStartValue","orgStartValue","polyEndValue","orgEndValue","Rsq","f(x)"]
        writer=csv.DictWriter(csvFile,csvHeader)
        writer.writeheader()

# %%
def lab1():
    mkfile()
    i=0
    count=1
    stop=False
    startPt=0
    endPt=0
    delta=0
    itl=[]
    fx=[]
    '''
    plot(t,v,'-')
    plot(t,sgf,'-')
    '''
    print(len(t))
    while(startPt<=(len(t)-1)):
        x=[]
        y=[]
        vt=[]
        for i in range(startPt,len(t)):
                if(abs(sgf[startPt]-sgf[i])<=0.2)  and i<(len(t)-1):
                    x.append(t[i])
                    y.append(float(sgf[i]))
                    vt.append(float(v[i]))
                else:
                    delta=i-startPt
                    endPt=i
                    x.append(t[i])
                    y.append(float(sgf[i]))
                    vt.append(float(v[i]))
                    break
        tp =polyfit(x,vt,2)
        #cs=CubicSpline(x,y)
        itl.append(count)
        itl.append(startPt)
        itl.append(endPt)
        fx.append(tp[0])
        fx.append(tp[1])
        fx.append(tp[2])
        f=poly1d(tp)
        ys_line=polyval(tp,x)
        rsqSGF=coeff_of_determination(array(y),ys_line)
        rsqTT=coeff_of_determination(array(vt),ys_line)
        print(count,'.'," start : ",'{:>4d}'.format(startPt),"  end : ",endPt," polyStartValue : ",'%.2f' % round(ys_line[0], 2),\
              " orgStartValue : ",v[endPt], " sgfStartValue : ",'%.2f' % round(sgf[startPt], 2)) 
        print( '%44s' %(" "),"polyEndValue :",'%.2f' % round(ys_line[delta],2),"orgEndValue : ",v[startPt],\
              "sgfEndValue : ",'%.2f' % round(sgf[startPt], 2))
        print('%44s' %(" "),"Rsq(Orig) : ",'%.3f ' % round(rsqTT,3),"Rsq(SGF) : ",'%.3f ' % round(rsqSGF,3))
        count+=1                
        print() 
        plot(x,ys_line,'r-')
        plot(t, v, 'bo', t,cs(t), 'r--',x,ys_line,'g-')
        legend(['Raw_data',  'Cubic_Spline','Savitzky-Golay'], loc='best')
        with open('pt.csv','a')as csvfile:
            csvHeader=["start","end","polyStartValue","orgStartValue","polyEndValue","orgEndValue","Rsq","f(x)"]
            writer=csv.DictWriter(csvfile,csvHeader)
            writer.writerow({"start":startPt ,"end":endPt,"polyStartValue":ys_line[0],\
                             "orgStartValue":v[endPt],"polyEndValue":ys_line[delta],"orgEndValue":v[startPt],"Rsq":rsqTT,"f(x)":tp})
        startPt= endPt+1

# %%
itl=[]
fx=[]
def lab2():
    mkfile()
    count=1
    stop=False
    startPt=0
    endPt=0
    delta=0
    d=0
    rsqSGF=0.0
    rsqTT=0.0
    '''
    plot(t,v,'-')
    plot(t,sgf,'-')
    '''
    plot(t,v,'-')
    plot(t,sgf,'-')
    print(len(t))
    d=int(len(t)/4)
    c=0
    while(startPt<(len(t)-1)):
        x=[]
        y=[]
        vt=[]
    
        for i in range(startPt,d):
            if(i<(d-1)) and (i<(len(t)-1)) and (abs(sgf[startPt]-sgf[i])<=2) :
                x.append(t[i])
                y.append(float(sgf[i]))
                vt.append(float(v[i]))
            else:
                delta=i-startPt
                endPt=i
                x.append(t[i])
                y.append(float(sgf[i]))
                vt.append(float(v[i]))
                break
        tp =polyfit(x,y,2)
        f=poly1d(tp)
        ys_line=polyval(tp,x)
        rsqSGF=coeff_of_determination(array(y),ys_line)
        rsqTT=coeff_of_determination(array(vt),ys_line)
        if(rsqSGF>=0.89) or ((d-10)<=startPt) :         
            print(f)
            print(count,'.'," start : ",'{:>4d}'.format(startPt),"  end : ",endPt," polyStartValue : ",'%.2f' % round(ys_line[0], 2),\
                  " orgStartValue : ",v[endPt], " sgfStartValue : ",'%.2f' % round(sgf[startPt], 2)) 
            print( '%44s' %(" "),"polyEndValue :",'%.2f' % round(ys_line[delta],2),"orgEndValue : ",v[startPt],\
                  "sgfEndValue : ",'%.2f' % round(sgf[startPt], 2))
            print('%44s' %(" "),"Rsq(Orig) : ",'%.3f ' % round(rsqTT,3),"Rsq(SGF) : ",'%.3f ' % round(rsqSGF,3))           
            print()
            plot(x,ys_line,'r-')
            with open('pt.csv','a')as csvfile:
                csvHeader=["start","end","polyStartValue","orgStartValue","polyEndValue","orgEndValue","Rsq","f(x)"]
                writer=csv.DictWriter(csvfile,csvHeader)
                writer.writerow({"start":startPt ,"end":endPt,"polyStartValue":ys_line[0],\
                                 "orgStartValue":v[endPt],"polyEndValue":ys_line[delta],"orgEndValue":v[startPt],"Rsq":rsqTT,"f(x)":tp})  
            itl.append(count)
            itl.append(startPt)
            itl.append(endPt)
            fx.append(tp[0])
            fx.append(tp[1])
            fx.append(tp[2])
            count+=1     
            d=endPt+int((len(t)-delta)/2)
            startPt= endPt+1
            print("round :",c)
           
        else:
             d-=10
        c+=1

# %%
lab2()
# Out:
# 1285
#             2
# -3.781e-05 x + 0.005672 x + 12.75
# 1 .  start :     0   end :  306  polyStartValue :  12.75  orgStartValue :  10.7  sgfStartValue :  13.06
#                                              polyEndValue : 10.94 orgEndValue :  13.2 sgfEndValue :  13.06
#                                              Rsq(Orig) :  0.788  Rsq(SGF) :  0.919
#
# round : 0
#            2
# 8.743e-05 x - 0.04919 x + 17.62
# 2 .  start :   307   end :  394  polyStartValue :  10.76  orgStartValue :  11.7  sgfStartValue :  10.84
#                                              polyEndValue : 11.81 orgEndValue :  10.7 sgfEndValue :  10.84
#                                              Rsq(Orig) :  0.612  Rsq(SGF) :  0.897
#
# round : 41
#             2
# -1.356e-05 x + 0.03898 x - 1.941
# 3 .  start :   395   end :  470  polyStartValue :  11.34  orgStartValue :  13.7  sgfStartValue :  11.51
#                                              polyEndValue : 13.38 orgEndValue :  11.7 sgfEndValue :  11.51
#                                              Rsq(Orig) :  0.799  Rsq(SGF) :  0.897
#
# round : 42
#           2
# 0.001616 x - 1.466 x + 345.3
# 4 .  start :   471   end :  496  polyStartValue :  13.49  orgStartValue :  16.1  sgfStartValue :  13.58
#                                              polyEndValue : 15.91 orgEndValue :  13.2 sgfEndValue :  13.58
#                                              Rsq(Orig) :  0.844  Rsq(SGF) :  0.941
#
# round : 43
#           2
# -0.03705 x + 37.1 x - 9268
# 5 .  start :   497   end :  505  polyStartValue :  16.10  orgStartValue :  15.6  sgfStartValue :  16.06
#                                              polyEndValue : 15.85 orgEndValue :  16.1 sgfEndValue :  16.06
#                                              Rsq(Orig) :  0.588  Rsq(SGF) :  0.921
#
# round : 106
#            2
# -0.008216 x + 8.535 x - 2199
# 6 .  start :   506   end :  532  polyStartValue :  16.08  orgStartValue :  16.6  sgfStartValue :  16.13
#                                              polyEndValue : 16.25 orgEndValue :  16.1 sgfEndValue :  16.13
#                                              Rsq(Orig) :  0.685  Rsq(SGF) :  0.958
#
# round : 168
#           2
# 0.008748 x - 9.177 x + 2422
# 7 .  start :   533   end :  540  polyStartValue :  16.54  orgStartValue :  18.1  sgfStartValue :  16.57
#                                              polyEndValue : 18.01 orgEndValue :  16.1 sgfEndValue :  16.57
#                                              Rsq(Orig) :  0.798  Rsq(SGF) :  0.994
#
# round : 231
#           2
# 0.007815 x - 8.452 x + 2303
# 8 .  start :   541   end :  559  polyStartValue :  18.00  orgStartValue :  20.5  sgfStartValue :  18.17
#                                              polyEndValue : 20.60 orgEndValue :  18.1 sgfEndValue :  18.17
#                                              Rsq(Orig) :  0.708  Rsq(SGF) :  0.912
#
# round : 232
#           2
# -0.02152 x + 24.42 x - 6909
# 9 .  start :   560   end :  571  polyStartValue :  20.30  orgStartValue :  21.0  sgfStartValue :  20.40
#                                              polyEndValue : 21.26 orgEndValue :  21.0 sgfEndValue :  20.40
#                                              Rsq(Orig) :  0.460  Rsq(SGF) :  0.973
#
# round : 295
#           2
# 0.002431 x - 2.883 x + 874.4
# 10 .  start :   572   end :  627  polyStartValue :  20.63  orgStartValue :  21.5  sgfStartValue :  20.89
#                                              polyEndValue : 22.36 orgEndValue :  21.5 sgfEndValue :  20.89
#                                              Rsq(Orig) :  0.745  Rsq(SGF) :  0.915
#
# round : 354
#           2
# 0.009221 x - 11.7 x + 3732
# 11 .  start :   628   end :  651  polyStartValue :  21.55  orgStartValue :  23.4  sgfStartValue :  21.47
#                                              polyEndValue : 23.70 orgEndValue :  21.5 sgfEndValue :  21.47
#                                              Rsq(Orig) :  0.863  Rsq(SGF) :  0.948
#
# round : 414
#           2
# 0.004741 x - 6.082 x + 1973
# 12 .  start :   652   end :  661  polyStartValue :  23.00  orgStartValue :  23.9  sgfStartValue :  23.16
#                                              polyEndValue : 24.29 orgEndValue :  23.4 sgfEndValue :  23.16
#                                              Rsq(Orig) :  0.460  Rsq(SGF) :  0.855
#
# round : 477
#          2
# 0.02622 x - 35.44 x + 1.199e+04
# 13 .  start :   662   end :  666  polyStartValue :  23.55  orgStartValue :  21.0  sgfStartValue :  23.51
#                                              polyEndValue : 21.09 orgEndValue :  23.9 sgfEndValue :  23.51
#                                              Rsq(Orig) :  0.936  Rsq(SGF) :  0.997
#
# round : 478
#          2
# 0.02098 x - 28.39 x + 9622
# 14 .  start :   667   end :  680  polyStartValue :  20.67  orgStartValue :  19.0  sgfStartValue :  20.71
#                                              polyEndValue : 18.98 orgEndValue :  21.0 sgfEndValue :  20.71
#                                              Rsq(Orig) :  0.819  Rsq(SGF) :  0.945
#
# round : 479
#           2
# 0.008129 x - 11.26 x + 3913
# 15 .  start :   681   end :  705  polyStartValue :  18.35  orgStartValue :  18.6  sgfStartValue :  18.50
#                                              polyEndValue : 18.63 orgEndValue :  18.6 sgfEndValue :  18.50
#                                              Rsq(Orig) :  0.714  Rsq(SGF) :  0.907
#
# round : 541
#           2
# -0.01349 x + 19.23 x - 6832
# 16 .  start :   706   end :  714  polyStartValue :  18.76  orgStartValue :  19.5  sgfStartValue :  18.80
#                                              polyEndValue : 19.34 orgEndValue :  18.6 sgfEndValue :  18.80
#                                              Rsq(Orig) :  0.627  Rsq(SGF) :  0.951
#
# round : 604
#          2
# 0.03184 x - 45.67 x + 1.639e+04
# 17 .  start :   715   end :  721  polyStartValue :  19.16  orgStartValue :  19.5  sgfStartValue :  19.13
#                                              polyEndValue : 19.53 orgEndValue :  19.5 sgfEndValue :  19.13
#                                              Rsq(Orig) :  0.467  Rsq(SGF) :  0.955
#
# round : 668
#           2
# 0.001422 x - 2.274 x + 920.1
# 18 .  start :   722   end :  729  polyStartValue :  19.68  orgStartValue :  18.1  sgfStartValue :  19.61
#                                              polyEndValue : 18.21 orgEndValue :  19.5 sgfEndValue :  19.61
#                                              Rsq(Orig) :  0.715  Rsq(SGF) :  0.982
#
# round : 732
#           2
# -0.02546 x + 37.47 x - 1.377e+04
# 19 .  start :   730   end :  737  polyStartValue :  18.45  orgStartValue :  19.5  sgfStartValue :  18.51
#                                              polyEndValue : 19.25 orgEndValue :  18.6 sgfEndValue :  18.51
#                                              Rsq(Orig) :  0.690  Rsq(SGF) :  0.976
#
# round : 796
#          2
# 0.01365 x - 20.21 x + 7499
# 20 .  start :   738   end :  745  polyStartValue :  19.07  orgStartValue :  19.5  sgfStartValue :  19.08
#                                              polyEndValue : 19.29 orgEndValue :  19.0 sgfEndValue :  19.08
#                                              Rsq(Orig) :  0.335  Rsq(SGF) :  0.977
#
# round : 860
#           2
# 0.004336 x - 6.529 x + 2477
# 21 .  start :   746   end :  773  polyStartValue :  19.19  orgStartValue :  20.5  sgfStartValue :  19.23
#                                              polyEndValue : 20.74 orgEndValue :  19.0 sgfEndValue :  19.23
#                                              Rsq(Orig) :  0.785  Rsq(SGF) :  0.925
#
# round : 922
#          2
# 0.01645 x - 25.71 x + 1.007e+04
# 22 .  start :   774   end :  791  polyStartValue :  20.51  orgStartValue :  21.0  sgfStartValue :  20.34
#                                              polyEndValue : 21.16 orgEndValue :  20.5 sgfEndValue :  20.34
#                                              Rsq(Orig) :  0.720  Rsq(SGF) :  0.891
#
# round : 984
#            2
# -0.007714 x + 12.28 x - 4863
# 23 .  start :   792   end :  814  polyStartValue :  21.66  orgStartValue :  20.0  sgfStartValue :  21.23
#                                              polyEndValue : 19.20 orgEndValue :  21.5 sgfEndValue :  21.23
#                                              Rsq(Orig) :  0.719  Rsq(SGF) :  0.905
#
# round : 1046
#            2
# 0.0005269 x - 1.032 x + 511.4
# 24 .  start :   815   end :  829  polyStartValue :  19.99  orgStartValue :  17.6  sgfStartValue :  19.87
#                                              polyEndValue : 17.66 orgEndValue :  19.5 sgfEndValue :  19.87
#                                              Rsq(Orig) :  0.885  Rsq(SGF) :  0.989
#
# round : 1047
#            2
# 0.0001632 x - 0.3532 x + 198.4
# 25 .  start :   830   end :  857  polyStartValue :  17.67  orgStartValue :  15.6  sgfStartValue :  17.58
#                                              polyEndValue : 15.56 orgEndValue :  17.6 sgfEndValue :  17.58
#                                              Rsq(Orig) :  0.835  Rsq(SGF) :  0.979
#
# round : 1048
#            2
# -6.13e-05 x + 0.1083 x - 32.44
# 26 .  start :   858   end :  1071  polyStartValue :  15.36  orgStartValue :  13.2  sgfStartValue :  15.42
#                                              polyEndValue : 13.24 orgEndValue :  15.6 sgfEndValue :  15.42
#                                              Rsq(Orig) :  0.872  Rsq(SGF) :  0.949
#
# round : 1049
#           2
# -0.01357 x + 29.11 x - 1.559e+04
# 27 .  start :  1072   end :  1076  polyStartValue :  13.35  orgStartValue :  13.2  sgfStartValue :  13.34
#                                              polyEndValue : 13.18 orgEndValue :  13.7 sgfEndValue :  13.34
#                                              Rsq(Orig) :  0.176  Rsq(SGF) :  0.959
#
# round : 1103
#          2
# 0.01138 x - 24.59 x + 1.33e+04
# 28 .  start :  1077   end :  1085  polyStartValue :  13.03  orgStartValue :  13.2  sgfStartValue :  13.02
#                                              polyEndValue : 13.09 orgEndValue :  13.2 sgfEndValue :  13.02
#                                              Rsq(Orig) :  0.290  Rsq(SGF) :  0.819
#
# round : 1167
#          2
# 0.01682 x - 36.62 x + 1.995e+04
# 29 .  start :  1086   end :  1092  polyStartValue :  13.03  orgStartValue :  12.7  sgfStartValue :  13.00
#                                              polyEndValue : 13.07 orgEndValue :  13.2 sgfEndValue :  13.00
#                                              Rsq(Orig) :  -0.074  Rsq(SGF) :  0.824
#
# round : 1231
#            2
# -3.32e-05 x + 0.08651 x - 42.35
# 30 .  start :  1093   end :  1284  polyStartValue :  12.54  orgStartValue :  13.7  sgfStartValue :  13.03
#                                              polyEndValue : 13.99 orgEndValue :  13.2 sgfEndValue :  13.03
#                                              Rsq(Orig) :  0.743  Rsq(SGF) :  0.901
#
# round : 1232

# %%
n=0
count=28

while(n<5) and ((count-2)*3<=len(itl)):
    x=[]
    y=[]
    vt=[]
    tp=array([0.0,0.0,0.0])
    itl_count=(count-2)*3

    for i in range(itl[itl_count-2] ,itl[itl_count-1]+1  ):
        x.append(t[i])
        y.append(float(sgf[i]))
        vt.append(float(v[i]))

   # x.append(itl[itl_count-1]+1) 
   # y.append(float(sgf[itl[itl_count-1]+1]))
   # vt.append(float(v[itl[itl_count-1]+1]))
    plot(x,vt,'bo')
    plot(x,y,'r-')   
    tp1=polyfit(x,y,2)
    tp[0],tp[1] ,tp[2]=fx[itl_count-3],fx[itl_count-2],fx[itl_count-1]
    f=poly1d(tp)
    f1=poly1d(tp)
    ytp=polyval(tp,x)
    rsqSGF=coeff_of_determination(array(y),ytp)
    print(ytp)
    print('{:>3d}.  {:>5d} - {:>5d}:  Rsq(SGF):{:5.3f}  ls={:5.3f}'.format(count-2,itl[itl_count-2],itl[itl_count-1],rsqSGF,least_square(tp,y,len(x),2,x)))  
    print(f)
    print()
