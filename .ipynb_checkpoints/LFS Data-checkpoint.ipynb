# %%
# -*- coding: utf-8 -*
import csv
data=[]
f = open('0207T1.csv', 'r')
for row in csv.DictReader(f):
    data.append(row['值'])
f.close()

# %%
print(data)
# Out:
# ['10.3', '10.7', '10.7', '10.7', '10.7', '10.7', '10.7', '10.7', '10.7', '10.7', '10.7', '10.3', '10.7', '10.7', '10.7', '10.7', '10.3', '10.7', '10.7', '10.7', '10.7', '10.7', '10.7', '10.7', '10.7', '10.7', '10.3', '10.3', '10.7', '10.7', '10.7', '10.7', '10.7', '10.7', '10.7', '10.3', '10.3', '10.3', '10.7', '10.7', '10.3', '10.7', '10.3', '10.3', '10.7', '10.3', '10.3', '9.8', '10.3', '10.3', '10.3', '10.3', '9.8', '9.8', '10.3', '10.3', '10.3', '9.8', '10.3', '9.8', '9.8', '9.8', '9.8', '9.3', '9.8', '9.8', '9.8', '9.8', '9.3', '9.8', '9.3', '9.8', '9.8', '9.8', '9.8', '10.3', '9.8', '9.8', '10.3', '9.8', '10.3', '9.8', '10.3', '9.8', '10.3', '10.3', '10.3', '10.3', '10.3', '10.3', '10.3', '10.3', '10.3', '10.3', '10.3', '10.7', '10.3', '10.7', '10.3', '10.3', '10.3', '10.3', '10.3', '10.3', '10.3', '10.7', '10.3', '10.3', '10.7', '10.7', '9.8', '10.3', '10.3', '10.3', '10.7', '10.3', '10.3', '10.3', '10.3', '10.3', '10.3', '10.3', '10.7', '10.7', '10.3', '10.7', '10.7', '10.3',
# ...

# %%
import matplotlib.pyplot as plt
def plotData(plt, data):
  x = [p[0] for p in data]
  y = [p[1] for p in data]
  plt.plot(x, y, '-o')
data_1 = [
  (1,2), (3,4), (5,2), (7,5), (9,8)
]
data_2 = [
  (1,1), (3,6), (3,9), (7,9), (9,3)
]
plotData(plt, data_1)
plotData(plt, data_2)
plt.show()
